# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']="/content/gdrive/MyDrive/Kaggle"

# %%
# %cd /content/gdrive/MyDrive/Kaggle
# Out:
# /content/gdrive/MyDrive/Kaggle

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/Kaggle'

# %%
# import libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, cv2

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import  Dropout,Flatten, Conv2D,MaxPooling2D, Dense
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings('ignore')

# %%
# create a CNN model (same as the saved one)
model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape=(96,96,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(96,96,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,kernel_size=(3,3),input_shape=(96,96,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(96,96,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128))
model.add(Dropout(0.4))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer=Adam(),loss='binary_crossentropy',
             metrics=[tf.keras.metrics.AUC()])

# %%
model.load_weights('Model_v1.h5')

# %%
# read sample submission in batches
i=0
j=500
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results1.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 35ms/step

# %%
len(preds)
# Out:
# 500

# %%
# read sample submission in batches
i=500
j=5000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results2.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 41ms/step
# ...
# ...
# 1/1 [==============================] - 0s 38ms/step

# %%
len(preds)
# Out:
# 4500

# %%
# read sample submission in batches
i=5000
j=15000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results3.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 40ms/step
# ...
# ...
# 1/1 [==============================] - 0s 51ms/step

# %%
# read sample submission in batches
i=15000
j=25000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results4.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 56ms/step
# ...
# ...
# 1/1 [==============================] - 0s 82ms/step

# %%
# read sample submission in batches
i=25000
j=35000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results5.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 48ms/step
# ...
# ...
# 1/1 [==============================] - 0s 56ms/step

# %%
# read sample submission in batches
i=35000
j=40000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results6.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 29ms/step
# ...
# ...
# 1/1 [==============================] - 0s 18ms/step

# %%
len(SS)
# Out:
# 57458

# %%
# read sample submission in batches
i=40000
j=50000
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results7.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 44ms/step
# ...
# ...
# 1/1 [==============================] - 0s 17ms/step

# %%
# read sample submission in batches
i=56500
j=57458
# j=57458
SS = pd.read_csv('sample_submission.csv')
results = pd.DataFrame()
results['id'] = SS.iloc[i:j]['id']
preds=[]

for image_id in SS.iloc[i:j]['id']:
    image = Image.open('test/'+ image_id+'.tif')
    image = image.resize((96,96))
    image = np.expand_dims(image,axis=0)/255
    res = np.ravel(np.round(model.predict(image)))[0]
    preds.append(res)

results['label'] = preds

results.to_csv('results12.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 38ms/step

# %%
df1 = pd.read_csv('results1.csv')
df2 = pd.read_csv('results2.csv')
df3 = pd.read_csv('results3.csv')
df4 = pd.read_csv('results4.csv')
df5 = pd.read_csv('results5.csv')
df6 = pd.read_csv('results6.csv')
df7 = pd.read_csv('results7.csv')
df8 = pd.read_csv('results8.csv')
df9 = pd.read_csv('results9.csv')
df10 = pd.read_csv('results10.csv')
df11 = pd.read_csv('results11.csv')
df12 = pd.read_csv('results12.csv')

# %%
submission = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],axis=0)

# %%
submission = submission.drop('Unnamed: 0',axis=1)
submission.reset_index(inplace=True)

# %%
submission.to_csv('submission1.csv',index=False)

# %%
submission = submission.drop('index',axis=1)
submission
# Out:
#                                              id  label
# 0      0b2ea2a822ad23fdb1b5dd26653da899fbd2c0d5    0.0
# 1      95596b92e5066c5c52466c90b69ff089b39f2737    1.0
# 2      248e6738860e2ebcf6258cdc1f32f299e0c76914    0.0
# 3      2c35657e312966e9294eac6841726ff3a748febf    0.0
# 4      145782eb7caa1c516acbe2eda34d9a3f31c41fd6    1.0
# ...                                         ...    ...
# 57453  061847314ded6f81e1cd670748bfa2003442c9c7    0.0
# 57454  6f3977130212641fd5808210015a609c658dcbff    0.0
# 57455  46935f247278539eca74b54d07d666efb528a753    0.0
# 57456  a09bcae08a82120183352e0e869181b2911d3dc1    0.0
# 57457  d29233dc0b90c2e1a8fcedbc3e1234c3d4dbd55b    0.0
#
# [57458 rows x 2 columns]

# %%
submission.to_csv('submission1.csv',index=False)
